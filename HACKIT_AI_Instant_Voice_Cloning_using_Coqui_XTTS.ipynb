# %% [markdown]
# <a href="https://colab.research.google.com/github/hoodini/XTTS/blob/main/HACKIT_AI_Instant_Voice_Cloning_using_Coqui_XTTS.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# מטרת המחברת הזו לאפשר שכפול קול בחינם באמצעות שימוש בקוד שנקרא Coqui XTTS שמאפשר לנו לקחת דגימת קול של 3 שניות ומעלה - וכן, מספיק אפילו 3 שניות, כדי לשכפל קול של אדם וליצור הקלטה שלו מקלט טקסטואלי שנזין.
#
# כמובן שלא מדובר במודל מושלם אבל הוא עדיין מאפשר עבודה מאוד מעניינת עם שכפולי קול בחינם ובהחלט שווה להתנסות בו.
#
# שימו לב:
# - מספיק לצרף דגימת קול של 3 שניות, כמובן שאפשר יותר אבל לא פחות מ-3 שניות
# - אפשר לבחור את השפה אליה נרצה להמיר, למשל אם נעלה הקלטה באנגלית אבל נבחר בשפה צרפתית, נקבל קטע קול בצרפתית עם אותו קול של הדובר על אף שהוא דיבר באנגלית במקור
#
# מקווה שתפיקו ערך מהמחברת שלי, ***מוזמנים לפרגן בבירה :***
# https://www.buymeacoffee.com/hackit.co.il
#
# ובנוסף, מצרף קישור לכל הקהילות שלי - **הצטרפו לקהילות שלי!**
# https://linktree.com/hackit.co.il
#
# **יובל אבידני
# מייסד HACKIT.CO.IL**

# %% [markdown]
# **שלב 1 - התקנת החבילה והגדרות נוספות**

# %%
# %cd /content
# !git clone https://github.com/hoodini/XTTS
# %cd /content/XTTS
# !pip install -q gradio TTS
# Out:
# /content
# Cloning into 'XTTS'...
# remote: Enumerating objects: 21, done.
# remote: Counting objects: 100% (21/21), done.
# remote: Compressing objects: 100% (19/19), done.
# remote: Total 21 (delta 6), reused 0 (delta 0), pack-reused 0
# Receiving objects: 100% (21/21), 6.14 KiB | 6.14 MiB/s, done.
# Resolving deltas: 100% (6/6), done.
# /content/XTTS
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 20.2/20.2 MB 79.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 867.6/867.6 kB 63.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.2/66.2 kB 7.3 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 298.2/298.2 kB 35.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.7/75.7 kB 9.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 295.0/295.0 kB 31.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 138.7/138.7 kB 16.0 MB/s eta 0:00:00
# ...

# %% [markdown]
# **שלב 2 - הרצת התוכנה והפעלת הממשק**

# %%
# !python app.py
# Out:
#  > You must agree to the terms of service to use this model.
#  | > Please see the terms of service at https://coqui.ai/cpml.txt
#  | > "I have read, understood and agreed the Terms and Conditions." - [y/n]
#  | | > Y
#  > Downloading model to /root/.local/share/tts/tts_models--multilingual--multi-dataset--xtts_v1
# 100% 2.98G/2.99G [00:47<00:00, 47.4MiB/s]
# 100% 2.99G/2.99G [00:48<00:00, 61.5MiB/s]
# 100% 4.38k/4.38k [00:00<00:00, 8.36kiB/s]
# 100% 272k/272k [00:00<00:00, 28.0MiB/s]
#  > Model's license - CPML
#  > Check https://coqui.ai/cpml.txt for more info.
# 2023-09-26 08:57:17.900516: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
#  > Using model: xtts
# /usr/local/lib/python3.10/dist-packages/gradio/components/dropdown.py:101: UserWarning: The `max_choices` parameter is ignored when `multiselect` is False.
#   warnings.warn(
# ...
# Running on local URL:  http://127.0.0.1:7860
# ...
